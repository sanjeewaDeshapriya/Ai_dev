# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr

# %%
data=pd.read_csv("Book2.csv")
data
# Out:
#   Unnamed: 0  videos  days  subscribers  views
# 0  channel 1      30   150         1800  34000
# 1  channel 2      40   212         1950  41000
# 2  channel 3      50   179         2100  42500
# 3  channel 4      60   346         4300  54300
# 4  channel 5      70   280         4200  56000

# %%
model = lr()
x=data[['videos','days','subscribers']]
y=data.views
model.fit(x,y)
# Out:
# C:\Users\sanjeewa\anaconda3\envs\notebook\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\sanjeewa\anaconda3\envs\notebook\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\sanjeewa\anaconda3\envs\notebook\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
model.predict([[45,180,3100]])
# Out:
# C:\Users\sanjeewa\anaconda3\envs\notebook\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41483.5043287])

# %%
m,c=np.polyfit(data['videos'],y,1)

# %%
m
# Out:
# 572.9999999999997

# %%
x1=np.array(data.videos)
x2=np.array(data.days)
x3=np.array(data.subscribers)
y=np.array(data.views)
plt.figure()
plt.subplot(2,2,1)
plt.plot(x1,y)
plt.subplot(2,2,2)
plt.plot(x2,y)
plt.subplot(2,2,3)
plt.plot(x3,y)

# %%
plt.plot(x1,y,x2,y,x3,y)

# %%
model.coef_
# Out:
# array([3.81732131e+02, 4.21209097e+01, 3.54006782e-01])

# %%
model.intercept_
# Out:
# 15626.373669488305

# %%
b=model.coef_
i=model.intercept_
c=20
a=b[0]*45+b[1]*180+b[2]*3100+i
a
# Out:
# 41483.504328703006
